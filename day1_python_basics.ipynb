# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesharma12/python-basics/blob/main/day1_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Yogesh"
age = 25

print(f"my name is {name} and I am {age} years old")
# Out:
# my name is Yogesh and I am 25 years old

# %%
numbers = [1,2,3,4]
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
def square(x):
    return x*x
print(square(5))
# Out:
# 25
